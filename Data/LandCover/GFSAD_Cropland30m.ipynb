# %% [markdown]
# ## Title: GFSAD 30m Cropland Extent
#
# ### Description
# Global Food Security-support Analysis Data (GFSAD) Cropland Extent data from the GFSAD30 product.<br>
# The NASA Making Earth System Data Records for Use in Research Environments (MEaSUREs) Global Food Security-support Analysis Data (GFSAD) data product provides cropland extent data for nominal year 2015 at 30 meter resolution (GFSAD30). The monitoring of global cropland extent is critical for policymaking and provides important baseline data that are used in many agricultural cropland studies pertaining to water sustainability and food security. The GFSAD30 data product uses the pixel-based supervised classifier, Random Forest (RF), to retrieve cropland extent from a combination of Landsat 8 Operational Land Imager (OLI) and elevation derived from the Shuttle Radar Topography Mission (SRTM) Version 3 data products. Each GFSAD30 GeoTIFF file contains a cropland extent layer that defines areas of cropland, non-cropland, and water bodies over a 10° by 10° area across 7 regions - NACE North America, SACE South America, AUNZCHMOCE Australia, New Zealand, China, and Mongolia, AFCE Africa, EUCEARUMECE Europe, SAAFGIRCE South Asia, Afghanistan and Iran and SEACE South East Asia<br>
#
# Note the FLINT ready data has been resampled from 30m to 0.00025degrees.
#
# ### FLINT
# This dataset has been checked/pre-processed and is suitable for use in FLINT. Please adhere to individual dataset licence conditions and citations. Processed data can be accessed here: [Land Sector Datasets](https://datasets.mojaglobal.workers.dev/) https://datasets.mojaglobal.workers.dev/<br>
#
# ### Format
# <b>Extent: </b>Global coverage tiled 10° by 10° (441 tiles)<br>
# <b>Resolution:</b> Raster 0.00025-degree (note this has been resampled from ~0.000269)<br>
# <b>File type:</b> geotiff (.tif)<br>
# <b>Cordinate system:</b> EPSG:4326 (WGS84)<br>
# <b>Temporal Resolution: </b>2015 (except for North America dataset which is 2010)<br>
# <b>Size:</b>
#
# ### Original source
# Original tiled rasters accessed from: https://croplands.org/downloadLPDAAC (or direct https://lpdaac.usgs.gov/product_search/?query=gfsad&view=cards&sort=title or https://e4ftl01.cr.usgs.gov/MEASURES/ with NASA earthdata login) <br>
#
# Each GFSAD30 GeoTIFF file contains a cropland extent layer that defines areas of cropland (2), non-cropland (1), and water bodies (0). Pixel size 0.00026949459, 0.00026949459
#
# ### Licence
# All data products distributed by NASA's Land Processes Distributed Active Archive Center (LP DAAC) are available at no charge. All LP DAAC current data and products acquired through the LP DAAC have no restrictions on reuse, sale, or redistribution. The LP DAAC kindly requests that you properly cite the data in your research.
# https://lpdaac.usgs.gov/data/data-citation-and-policies/
#
#
# ### Citations
# /GFSAD30AFCE.001<br>
# Xiong, J., Thenkabail, S., P., Tilton, J.C., Gumma, K., M., Teluguntla, P., Congalton, G., R., Yadav, K., Dungan, J., Oliphant, J., A., Poehnelt, J., Smith, C., Massey, R. (2017). NASA Making Earth System Data Records for Use in Research Environments (MEaSUREs) Global Food Security-support Analysis Data (GFSAD) Cropland Extent 2015 Africa 30 m V001 [Data set]. NASA EOSDIS Land Processes DAAC. Accessed 2019-12-01 from https://doi.org/10.5067/MEaSUREs/GFSAD/GFSAD30AFCE.001<br>
# /GFSAD30AUNZCNMOCE.001<br>
# Teluguntla, P., Thenkabail, P.S., Xiong, J., Gumma, M.K., G., Congalton, R., Oliphant, J., A., Sankey, T., Poehnelt, J., Yadav, K., Massey, R., Phalke, A., Smith, C. (2017). NASA Making Earth System Data Records for Use in Research Environments (MEaSUREs) Global Food Security-support Analysis Data (GFSAD) Cropland Extent 2015 Australia, New Zealand, China, Mongolia 30 m V001 [Data set]. NASA EOSDIS Land Processes DAAC. Accessed 2019-12-01 from https://doi.org/10.5067/MEaSUREs/GFSAD/GFSAD30AUNZCNMOCE.001<br>
# /GFSAD30EUCEARUMECE.001<br>
# Phalke, A., Ozdogan, M., Thenkabail, S., P., G., Congalton, R., Yadav, K., Massey, R., Teluguntla, P., Poehnelt, J., Smith, C. (2017). NASA Making Earth System Data Records for Use in Research Environments (MEaSUREs) Global Food Security-support Analysis Data (GFSAD) Cropland Extent 2015 Europe, Central Asia, Russia, Middle East 30 m V001 [Data set]. NASA EOSDIS Land Processes DAAC. Accessed 2019-12-01 from https://doi.org/10.5067/MEaSUREs/GFSAD/GFSAD30EUCEARUMECE.001<br>
# /GFSAD30NACE.001<br>
# Massey, R., Sankey, T.T., Yadav, K., Congalton, R.G., Tilton, J.C., Thenkabail, P.S. (2017). NASA Making Earth System Data Records for Use in Research Environments (MEaSUREs) Global Food Security-support Analysis Data (GFSAD) Cropland Extent 2010 North America 30 m V001 [Data set]. NASA EOSDIS Land Processes DAAC. Accessed 2019-12-01 from https://doi.org/10.5067/MEaSUREs/GFSAD/GFSAD30NACE.001<br>
# /GFSAD30SAAFGIRCE.001/ <br>
# Gumma, M.K., Thenkabail, P.S., Teluguntla, P., Oliphant, A.J., Xiong, J., G., Congalton, R., Yadav, K., Phalke, A., Smith, C. (2017). NASA Making Earth System Data Records for Use in Research Environments (MEaSUREs) Global Food Security-support Analysis Data (GFSAD) Cropland Extent 2015 South Asia, Afghanistan, Iran 30 m V001 [Data set]. NASA EOSDIS Land Processes DAAC. Accessed 2019-12-01 from https://doi.org/10.5067/MEaSUREs/GFSAD/GFSAD30SAAFGIRCE.001<br>
# /GFSAD30SACE.001<br>
# Zhong, Y., Giri, C., Thenkabail, P.S., Teluguntla, P., Congalton, G., R., Yadav, K., Oliphant, J., A., Xiong, J., Poehnelt, J., Smith, and, C. (2017). NASA Making Earth System Data Records for Use in Research Environments (MEaSUREs) Global Food Security-support Analysis Data (GFSAD) Cropland Extent 2015 South America 30 m V001 [Data set]. NASA EOSDIS Land Processes DAAC. Accessed 2019-12-01 from https://doi.org/10.5067/MEaSUREs/GFSAD/GFSAD30SACE.001<br>
# /GFSAD30SEACE.001<br>
# Oliphant, J., A., Thenkabail, S., P., Teluguntla, P., Xiong, Congalton, J., G., R., Yadav, K., Massey, R., Gumma, M.K., Smith, C. (2017). NASA Making Earth System Data Records for Use in Research Environments (MEaSUREs) Global Food Security-support Analysis Data (GFSAD) Cropland Extent 2015 Southeast Asia 30 m V001 [Data set]. NASA EOSDIS Land Processes DAAC. Accessed 2019-12-01 from https://doi.org/10.5067/MEaSUREs/GFSAD/GFSAD30SEACE.001
#
# ### Metadata
# Each GFSAD30 GeoTIFF file contains a cropland extent layer that defines areas of cropland (2), non-cropland (1), and water bodies (0). More information: https://croplands.org/home<br>
# Metadata for each region is described in the Algorithm Theoretical Basis Document (ATBD):<br>
# - https://lpdaac.usgs.gov/documents/148/GFSAD30AUNZCNMOCE_ATBD.pdf
# - https://lpdaac.usgs.gov/documents/153/GFSAD30AFCE_ATBD.pdf
# - https://lpdaac.usgs.gov/documents/154/GFSAD30EUCEARUMECE_ATBD.pdf
# - https://lpdaac.usgs.gov/documents/157/GFSAD30NACE_ATBD.pdf
# - https://lpdaac.usgs.gov/documents/160/GFSAD30SAAFGIRCE_ATBD.pdf
# - https://lpdaac.usgs.gov/documents/163/GFSAD30SACE_ATBD.pdf
# - https://lpdaac.usgs.gov/documents/166/GFSAD30SEACE_ATBD.pdf
#
# Filenaming:<br>
# GFSAD30*Region*_Year_GridTile(latlong from bottom left)_001(version)_ProcessingDate(YYYYJJJHHMMSS).tif<br>
#
# ### Notes
# The regional products overlap but data is not shared e.g. E20S120 overlaps AusNZ with SE Asia but data from either is not shown in the other. To run a global raster, use 'Maximum' when merging/mosaicing rasters.
#
# Known issues are outlined in the project metadata:
# - https://lpdaac.usgs.gov/documents/148/GFSAD30AUNZCNMOCE_ATBD.pdf (page 20)
# - https://lpdaac.usgs.gov/documents/153/GFSAD30AFCE_ATBD.pdf (page 22)
# - https://lpdaac.usgs.gov/documents/154/GFSAD30EUCEARUMECE_ATBD.pdf (Page 21)
# - https://lpdaac.usgs.gov/documents/157/GFSAD30NACE_ATBD.pdf (page 39) Note: 2010 data only (other datasets are 2015)
# - https://lpdaac.usgs.gov/documents/160/GFSAD30SAAFGIRCE_ATBD.pdf (Page 18)
# - https://lpdaac.usgs.gov/documents/163/GFSAD30SACE_ATBD.pdf (Page 18)
# - https://lpdaac.usgs.gov/documents/166/GFSAD30SEACE_ATBD.pdf (page 19). Also note: certain small islands in the Pacific are not classified and therefore data for these areas are not provided<br>
#
# ### Processing
# Resampling to 0.00025 resolution completed in batch as per code below. Use this code to resample tiles or mosaics to another resolution.
#
# As for preprocessing from the original, as the original tiled data is not padded to the nearest degree - best practice is to mosaic (or virtual raster) at original resolution (in sections if computing power is a problem) then gdalwarp or export to tif rounding the bounding extents to the nearest 10th degree, and nearest neighbour resample to 0.00025 or other resolution. From here - these can be tiles using gdal retile making each tile 40000x40000 pixel height and width.

# %%
# Batch resample resolution all tiles gdal (this will not force the tiles to sit on the nearest degree)
for /R C:\inputfolder\GFSAD\ %f IN (*.tif) do gdalwarp.exe -co COMPRESS=DEFLATE -co PREDICTOR=2 -co ZLEVEL=9 -s_srs EPSG:4326 -tap -tr 0.00025 0.00025 -multi -r near -of GTiff %f C:\outputfolder\gfsad\tiles\%~nf.tif
