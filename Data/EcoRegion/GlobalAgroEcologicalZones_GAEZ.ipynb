# %% [markdown]
# ## Title: GAEZ Global Agro‐Ecological Zones (GAEZ v3.0)
#
# ### Description
# The term GAEZ refers to the Agro-Ecological Zones system, developed by the Food and Agriculture Organization of the United Nations (FAO) in collaboration with the International Institute for Applied Systems Analysis (IIASA). The approach enables rational land-use planning on the basis of an inventory of land resources and an evaluation of their biophysical limitations and potentials for crop production. The GAEZ programs utilize the land resources inventory to assess all feasible agricultural land-use options and to quantify expected production of cropping activities relevant in a particular agro-ecological context, for specified management conditions and levels of inputs. The characterization of land resources includes all relevant components of climate, soils and landform, which are basic for the supply of water, energy, nutrients and physical support to plants.<br>
#
# GAEZ provides a standardized framework for the characterization of climate, soil and terrain conditions relevant to agricultural production. It identifies crop-specific limitations of climate, soil and terrain resources in a consistent and empirically founded way. It systematically computes spatial and temporal data on maximum potential and attainable crop yields as well as expected sustainable agricultural production potentials at different specified levels of inputs and management conditions. The GAEZ computations were completed for a range of climatic conditions, including a reference climate (average of period 1961-1990), individual historical years of 1901 to 2009 (climate data for individual years for the period 1960-2000 are uploaded in GAEZ v3.0 Data Portal) and future climate based on the published outputs of various global and regional climate models combined with IPCC scenarios. Hence, the GAEZ results consistently quantify impacts on land productivity of historical climate variability as well as of potential future climate change.<br>
#
# The [GAEZ portal](https://webarchive.iiasa.ac.at/Research/LUC/GAEZv3.0/) contains many different datasets and timelines (soil, climate, crop yields, themral regimes, land resources and protected areas) that can be downloaded (one by one) for use in FLINT (includes historic, baseline and future climate scenarios). Only a subset of what is available have been preprocessed for FLINT here but please use the below code to convert any GAEZ portal dataset to FLINT ready format, specifying desired cell size.<br>
#
# 2015 updates to crop yield datasets area available: https://dataverse.harvard.edu/dataverse/GAEZ_plus_2015;jsessionid=8e89bcad5b094e99ede8ba1ff760
#
# ### FLINT
# This dataset has been checked/pre-processed and is suitable for use in FLINT. Please adhere to individual dataset licence conditions and citations. Processed data can be accessed here: [Land Sector Datasets](https://datasets.mojaglobal.workers.dev/) https://datasets.mojaglobal.workers.dev/
#
# ### Format
# <b>Extent: </b>Global coverage {-90, -180, 90, 180}<br>
# <b>Resolution:</b> Raster 0.05-degree (multiple FLOAT and INTEGER)<br>
# <b>File type:</b> geotiff (.tif)<br>
# <b>Cordinate system:</b> EPSG:4326 (WGS84)<br>
# <b>Temporal Resolution: </b>historic 1961-2000, baseline 1961-1990 and future scenarios 2020s, 2050s and 2080s<br>
# <b>Size:</b>177MB<br>
# Datasets processed:<br>
# - GlobalAgroEcologicalZones_GAEZ.geojson
# - GlobalAgroEcologicalZones_GAEZ.tif
# - AgroClimate
#     - ThermalZones_A2_2050s.tif
#     - ThermalZones_A2_2020s.tif
#     - ThermalClimates_A2_2050s.tif
#     - ThermalClimates_A2_2020s.tif
#     - TempGrowingPeriod_A2_2050s.tif
#     - TempGrowingPeriod_A2_2020s.tif
#     - GrowingPeriodLength_A2_2050s.tif
#     - GrowingPeriodLength_A2_2020s.tif
#     - CVlengthofgrowingPeriod1961_90.tif
# - LandResource_Cultivated_GAEZ.tif
# - LandResource_DominanyLandCover_GAEZ.tif
# - LandResource_ForestLand_GAEZ.tif
# - ProtectedAreas_RestrictionsAgriculture_GAEZ.tif
# - ProtectedAreas_Types_GAEZ.tif
# - SoilResources_DominantSoil_GAEZ.tif
# - SoilResources_NutrientAvailability_GAEZ.tif
# - SoilResources_RainfedSoilTerrainSuitability_GAEZ.tif
# - SoilResources_RootingConditions_GAEZ.tif
# - Terrain_SlopeIndex_GAEZ.tif
# - WaterScarcity_GAEZ.tif
# - Fisher2008GAEZ
#
# ### Original source
# https://webarchive.iiasa.ac.at/Research/LUC/GAEZv3.0/ (login required).<br>
# Format: ASCII raster pixel size 0.083333333333 Origin -89.9167, -180.0000. Cordinate system: EPSG:4326 (WGS84)
#
# ### Licence
# Use of the Global Agro-ecological Zones Portal version 3.0 (hereafter referred to as "GAEZ v3.0") constitutes the acceptance of the Terms and Conditions which take affect on the date of first access to  the GAEZ v3.0 Portal and download data. User agreement: http://www.gaez.iiasa.ac.at/w/ctrl?_flow=Page&_view=View&_page=lic-&item=page_Lic
#
# Reproduction and dissemination of material contained in GAEZ v3.0 or educational, research, personal or other noncommercial purposes are authorized without any prior written permission from the copyright holders, provided IIASA and FAO are fully acknowledged. No part of GAEZ v3.0 data may be downloaded, stored in a retrieval system or transmitted by any means for resale or other commercial purposes without written permission of the copyright holders. Full acknowledgement and citation in any materials or publications derived in part or in whole from GAEZ data is required and must be cited as below.
#
# ### Citation
# IIASA/FAO, 2012. Global Agro‐ecological Zones (GAEZ v3.0). IIASA, Laxenburg, Austria and FAO,
# Rome, Italy.<br>
#
# Fischer, G., Nachtergaele, F.O., Prieler, S., Teixeira, E. , Toth, G., van Velthuizen, H., Verelst, L., & Wiberg, D. (IIASA/FAO 2012). Global Agro-ecological Zones (GAEZ v3.0)- Model Documentation. IIASA, Laxenburg, Austria and FAO, Rome, Italy.<br>
#
# 2000 series:
# Fischer, G., F. Nachtergaele, S. Prieler, H.T. van Velthuizen, L. Verelst, D. Wiberg, 2008. Global Agro-ecological Zones Assessment for Agriculture (GAEZ 2008). IIASA, Laxenburg, Austria and FAO, Rome, Italy.
#
# ### Metadata
# Please read https://webarchive.iiasa.ac.at/Research/LUC/GAEZv3.0/docs/GAEZ_Model_Documentation.pdf (includes legend descriptions for individual rasters) and
# https://webarchive.iiasa.ac.at/Research/LUC/GAEZv3.0/docs/FAQ.pdf <br>
#
# About Time Period...<br>
# Climate and agro-climatic data analyses are performed for: (i) individual historical years (1961-2000); (ii) average climatic conditions of a baseline period (1961-1990), and (iii) future climatic conditions (2020s, 2050s and 2080s -  future periods require selection of global circulation model/emission scenario combination and, where applicable, CO2 fertilization effect has to be switched ON or OFF). In addition, (iv) selected average results (and variability) are generated on the basis of climatic and agro-climatic analysis of individual historical years. And the 30-year average results (and variability) based on climate and agro-climatic analysis of historical years for the period 1961-1990.<br>
#
# Agro-Ecolgocial Zones (soil): <br>
# 1. Steep terrain
# 2. Artic/Cold
# 3. Desert/Arid
# 4. Irrigated Soils
# 5. Hydromorphic soils
# 6. Dry, good soils
# 7. Dry, moderate soils
# 8. Dry, poor soils
# 9. Moist, good soils
# 10. Moist, moderate soils
# 11. Moist, poor soils
# 12. Sub-humid, good soils
# 13. Sub-humid, moderate soils
# 14. Sub-humid, poor soils
# 15. Humid, good soils
# 16. Humid, moderate soils
# 17. Humid, poor soils
# 18. Water
#
# ### Notes
# Datasets are a combo of float and integer types with varying value ranges. Ascii raster cell resolution 0.0833 needs to be rounded to nearest multiple of a degree. Extents need to be expanded to full global coverage to allow for FLINT appropriate cell alignment (origin -180, -90, 180, 90). The GAEZ portal contains many different datasets and timelines (soil, climate, crop yields, themral regimes, land resources, population and protected areas) that can be downloaded for use in FLINT. Only a subset of what is available have been preprocessed. Use the below code to convert any GAEZ portal dataset to FLINT ready format, specifying desired cell size.<br>
#
# However, the GAEZv3 portal is a bit buggy and will not allow download of all datasets.
#
# ### Processing
# Use gdal code below to convert all ascii rasters in a directory to geoTIFF, specify outbounds to full global extent and nearest degree alighment (origin -180, -90, 180, 90).

# %%
# GDAL code to convert all ascii rasters in a directory to GTiff
# Specify infolder, outfolder and pixel size at -tr e.g. 0.05 0.05
for /R C:\infolder\ %f IN (*.tif) do gdalwarp.exe -co COMPRESS=DEFLATE -co PREDICTOR=2 -co ZLEVEL=9 -t_srs EPSG:4326 -tr 0.05 0.05 -tap -te -180 -90 180 90 -r near -of GTiff -multi  -overwrite %f C:\outfolder\%~nf.tif

# %%
# GDAL code to convert individual rasters to polygon (GeoJSON)
# Please repair geometry in QGIS after to remove non-simple geometry
python3 -m gdal_polygonize C:/GAEZ/data.tif C:/GAEZ/GAEZ_vVector.geojson -b 1 -f "GeoJSON" GAEZ_vVector Value
